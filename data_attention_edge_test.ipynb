# %%
import pandas as pd
import numpy as np
import pickle
import torch

# %%
#train = pd.read_csv('../Data/train.csv')
train = pd.read_csv('../Data/test.csv')
structures = pd.read_csv('../Data/structures.csv')

# %%
def map_atom_info(df, atom_idx):
    df = pd.merge(df, structures, how = 'left',
                  left_on  = ['molecule_name', f'atom_index_{atom_idx}'],
                  right_on = ['molecule_name',  'atom_index'])
    
    df = df.drop('atom_index', axis=1)
    df = df.rename(columns={'atom': f'atom_{atom_idx}',
                            'x': f'x_{atom_idx}',
                            'y': f'y_{atom_idx}',
                            'z': f'z_{atom_idx}'})
    return df

# %%
train = map_atom_info(train, 0)
train = map_atom_info(train, 1)

# %%
train
# Out:
#               id     molecule_name  atom_index_0  atom_index_1  type atom_0  \
# 0        4658147  dsgdb9nsd_000004             2             0  2JHC      H
# 1        4658148  dsgdb9nsd_000004             2             1  1JHC      H
# 2        4658149  dsgdb9nsd_000004             2             3  3JHH      H
# 3        4658150  dsgdb9nsd_000004             3             0  1JHC      H
# 4        4658151  dsgdb9nsd_000004             3             1  2JHC      H
# ...          ...               ...           ...           ...   ...    ...
# 2505537  7163684  dsgdb9nsd_133885            15             3  2JHC      H
# 2505538  7163685  dsgdb9nsd_133885            15             4  2JHC      H
# 2505539  7163686  dsgdb9nsd_133885            15             6  3JHC      H
# 2505540  7163687  dsgdb9nsd_133885            15             7  2JHC      H
# 2505541  7163688  dsgdb9nsd_133885            15             8  1JHC      H
#
#               x_0       y_0       z_0 atom_1       x_1       y_1       z_1
# 0       -1.661639  0.000000  1.000000      C  0.599539  0.000000  1.000000
# 1       -1.661639  0.000000  1.000000      C -0.599539  0.000000  1.000000
# 2       -1.661639  0.000000  1.000000      H  1.661639  0.000000  1.000000
# 3        1.661639  0.000000  1.000000      C  0.599539  0.000000  1.000000
# 4        1.661639  0.000000  1.000000      C -0.599539  0.000000  1.000000
# ...           ...       ...       ...    ...       ...       ...       ...
# 2505537  1.260745 -1.246754 -1.906767      C  0.271030 -1.618614  0.144805
# 2505538  1.260745 -1.246754 -1.906767      C  1.528454 -0.755123  0.339508
# 2505539  1.260745 -1.246754 -1.906767      C -0.057400  0.611210  0.541102
# 2505540  1.260745 -1.246754 -1.906767      C -0.095929  0.380424 -0.972098
# 2505541  1.260745 -1.246754 -1.906767      C  0.816694 -0.813067 -1.022360
#
# [2505542 rows x 13 columns]

# %%
centers = (train.loc[:,['x_0','y_0','z_0']].values + train.loc[:,['x_1','y_1','z_1']].values)/2

# %%
vector = train.loc[:,['x_0','y_0','z_0']].values - train.loc[:,['x_1','y_1','z_1']].values

# %%
norm = np.linalg.norm(vector,axis=1)[:,None]
vector = vector/norm

# %%
structures[['C', 'F', 'H', 'N', 'O']] = pd.get_dummies(structures.atom)

# %%
structures_gb = structures.groupby(['molecule_name'])

# %%
structures_gb = {k:v.loc[:,['x','y','z','C', 'F', 'H', 'N', 'O']].values for k,v in structures_gb}

# %%
def create(mol,c,v):
    X = mol[:,:3] - c
    r = np.matmul(X,v)
    R = np.linalg.norm(X - r[:,None]*v,axis=1)
    out = np.concatenate([r[:,None],R[:,None],mol[:,3:],np.broadcast_to(d,mol.shape[0])[:,None]],1)
    return out

# %%
feature_list = []
for i in range(train.shape[0]):
    mol = structures_gb[train.iloc[i]['molecule_name']]
    c,v,d = centers[i],vector[i],norm[i]
    feature_list.append(create(mol,c,v))

# %%
def numpy2torch(x):
    return torch.from_numpy(x.astype(np.float32))

# %%
feature_list = [numpy2torch(i) for i in feature_list]

# %%
with open('../Data/test_data_attention_node.pickle', 'wb') as handle:
    pickle.dump(feature_list, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
edge_X = torch.from_numpy(np.concatenate([pd.get_dummies(train.type).values,norm],1).astype(np.float32))

# %%
with open('../Data/test_data_attention_edge.pickle', 'wb') as handle:
    pickle.dump(edge_X, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
ind = torch.from_numpy(train.loc[:,['atom_index_0','atom_index_1']].values)

with open('../Data/test_data_ind.pickle', 'wb') as handle:
    pickle.dump(ind, handle, protocol=pickle.HIGHEST_PROTOCOL)
