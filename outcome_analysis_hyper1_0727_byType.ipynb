# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
pd.set_option('max_colwidth', 800)

# %%
results = [file for file in os.listdir('/home/will/Downloads/0727_bytype/') if 'result' in file]
df_list = []
for result in results:
    df = pd.read_csv('/home/will/Downloads/0727_bytype/'+result,na_values=0)
    df['file_name'] = result
    df_list.append(df)
df = pd.concat(df_list,ignore_index=True)#.fillna(1e4)

# %%
df
# Out:
#      reuse                                      block  \
# 0    False  <class 'functions_refactor.NNConv_block'>
# 1    False  <class 'functions_refactor.NNConv_block'>
# 2    False  <class 'functions_refactor.NNConv_block'>
# 3    False  <class 'functions_refactor.NNConv_block'>
# 4    False  <class 'functions_refactor.NNConv_block'>
# 5    False  <class 'functions_refactor.NNConv_block'>
# 6    False  <class 'functions_refactor.NNConv_block'>
# 7    False  <class 'functions_refactor.NNConv_block'>
# 8    False  <class 'functions_refactor.NNConv_block'>
# 9    False  <class 'functions_refactor.NNConv_block'>
# 10   False  <class 'functions_refactor.NNConv_block'>
# 11   False  <class 'functions_refactor.NNConv_block'>
# 12   False  <class 'functions_refactor.NNConv_block'>
# 13   False  <class 'functions_refactor.NNConv_block'>
# 14   False  <class 'functions_refactor.NNConv_block'>
# 15   False  <class 'functions_refactor.NNConv_block'>
# 16   False  <class 'functions_refactor.NNConv_block'>
# 17   False  <class 'functions_refactor.NNConv_block'>
# 18   False  <class 'functions_refactor.NNConv_block'>
# 19   False  <class 'functions_refactor.NNConv_block'>
# 20   False  <class 'functions_refactor.NNConv_block'>
# 21   False  <class 'functions_refactor.NNConv_block'>
# 22   False  <class 'functions_refactor.NNConv_block'>
# 23   False  <class 'functions_refactor.NNConv_block'>
# 24   False  <class 'functions_refactor.NNConv_block'>
# 25   False  <class 'functions_refactor.NNConv_block'>
# 26   False  <class 'functions_refactor.NNConv_block'>
# 27   False  <class 'functions_refactor.NNConv_block'>
# 28   False  <class 'functions_refactor.NNConv_block'>
# 29   False  <class 'functions_refactor.NNConv_block'>
# ..     ...                                        ...
# 770  False  <class 'functions_refactor.NNConv_block'>
# 771  False  <class 'functions_refactor.NNConv_block'>
# 772  False  <class 'functions_refactor.NNConv_block'>
# 773  False  <class 'functions_refactor.NNConv_block'>
# 774  False  <class 'functions_refactor.NNConv_block'>
# 775  False  <class 'functions_refactor.NNConv_block'>
# 776  False  <class 'functions_refactor.NNConv_block'>
# 777  False  <class 'functions_refactor.NNConv_block'>
# 778  False  <class 'functions_refactor.NNConv_block'>
# 779  False  <class 'functions_refactor.NNConv_block'>
# 780  False  <class 'functions_refactor.NNConv_block'>
# 781  False  <class 'functions_refactor.NNConv_block'>
# 782  False  <class 'functions_refactor.NNConv_block'>
# 783  False  <class 'functions_refactor.NNConv_block'>
# 784  False  <class 'functions_refactor.NNConv_block'>
# 785  False  <class 'functions_refactor.NNConv_block'>
# 786  False  <class 'functions_refactor.NNConv_block'>
# 787  False  <class 'functions_refactor.NNConv_block'>
# 788  False  <class 'functions_refactor.NNConv_block'>
# 789  False  <class 'functions_refactor.NNConv_block'>
# 790  False  <class 'functions_refactor.NNConv_block'>
# 791  False  <class 'functions_refactor.NNConv_block'>
# 792  False  <class 'functions_refactor.NNConv_block'>
# 793  False  <class 'functions_refactor.NNConv_block'>
# 794  False  <class 'functions_refactor.NNConv_block'>
# 795  False  <class 'functions_refactor.NNConv_block'>
# 796  False  <class 'functions_refactor.NNConv_block'>
# 797  False  <class 'functions_refactor.NNConv_block'>
# 798  False  <class 'functions_refactor.NNConv_block'>
# 799  False  <class 'functions_refactor.NNConv_block'>
#
#                                                head  \
# 0    <class 'functions_refactor.cat3HeadPool_type'>
# 1    <class 'functions_refactor.cat3HeadPool_type'>
# 2    <class 'functions_refactor.cat3HeadPool_type'>
# 3    <class 'functions_refactor.cat3HeadPool_type'>
# 4    <class 'functions_refactor.cat3HeadPool_type'>
# 5    <class 'functions_refactor.cat3HeadPool_type'>
# 6    <class 'functions_refactor.cat3HeadPool_type'>
# 7    <class 'functions_refactor.cat3HeadPool_type'>
# 8    <class 'functions_refactor.cat3HeadPool_type'>
# 9    <class 'functions_refactor.cat3HeadPool_type'>
# 10   <class 'functions_refactor.cat3HeadPool_type'>
# 11   <class 'functions_refactor.cat3HeadPool_type'>
# 12   <class 'functions_refactor.cat3HeadPool_type'>
# 13   <class 'functions_refactor.cat3HeadPool_type'>
# 14   <class 'functions_refactor.cat3HeadPool_type'>
# 15   <class 'functions_refactor.cat3HeadPool_type'>
# 16   <class 'functions_refactor.cat3HeadPool_type'>
# 17   <class 'functions_refactor.cat3HeadPool_type'>
# 18   <class 'functions_refactor.cat3HeadPool_type'>
# 19   <class 'functions_refactor.cat3HeadPool_type'>
# 20   <class 'functions_refactor.cat3HeadPool_type'>
# 21   <class 'functions_refactor.cat3HeadPool_type'>
# 22   <class 'functions_refactor.cat3HeadPool_type'>
# 23   <class 'functions_refactor.cat3HeadPool_type'>
# 24   <class 'functions_refactor.cat3HeadPool_type'>
# 25   <class 'functions_refactor.cat3HeadPool_type'>
# 26   <class 'functions_refactor.cat3HeadPool_type'>
# 27   <class 'functions_refactor.cat3HeadPool_type'>
# 28   <class 'functions_refactor.cat3HeadPool_type'>
# 29   <class 'functions_refactor.cat3HeadPool_type'>
# ..                                              ...
# 770  <class 'functions_refactor.cat3HeadPool_type'>
# 771  <class 'functions_refactor.cat3HeadPool_type'>
# 772  <class 'functions_refactor.cat3HeadPool_type'>
# 773  <class 'functions_refactor.cat3HeadPool_type'>
# 774  <class 'functions_refactor.cat3HeadPool_type'>
# 775  <class 'functions_refactor.cat3HeadPool_type'>
# 776  <class 'functions_refactor.cat3HeadPool_type'>
# 777  <class 'functions_refactor.cat3HeadPool_type'>
# 778  <class 'functions_refactor.cat3HeadPool_type'>
# 779  <class 'functions_refactor.cat3HeadPool_type'>
# 780  <class 'functions_refactor.cat3HeadPool_type'>
# 781  <class 'functions_refactor.cat3HeadPool_type'>
# 782  <class 'functions_refactor.cat3HeadPool_type'>
# 783  <class 'functions_refactor.cat3HeadPool_type'>
# 784  <class 'functions_refactor.cat3HeadPool_type'>
# 785  <class 'functions_refactor.cat3HeadPool_type'>
# 786  <class 'functions_refactor.cat3HeadPool_type'>
# 787  <class 'functions_refactor.cat3HeadPool_type'>
# 788  <class 'functions_refactor.cat3HeadPool_type'>
# 789  <class 'functions_refactor.cat3HeadPool_type'>
# 790  <class 'functions_refactor.cat3HeadPool_type'>
# 791  <class 'functions_refactor.cat3HeadPool_type'>
# 792  <class 'functions_refactor.cat3HeadPool_type'>
# 793  <class 'functions_refactor.cat3HeadPool_type'>
# 794  <class 'functions_refactor.cat3HeadPool_type'>
# 795  <class 'functions_refactor.cat3HeadPool_type'>
# 796  <class 'functions_refactor.cat3HeadPool_type'>
# 797  <class 'functions_refactor.cat3HeadPool_type'>
# 798  <class 'functions_refactor.cat3HeadPool_type'>
# 799  <class 'functions_refactor.cat3HeadPool_type'>
#
#                                        data  batch_size  dim  clip  layer1  \
# 0    ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 1    ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 2    ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 3    ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 4    ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 5    ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 6    ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 7    ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 8    ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 9    ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 10   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 11   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 12   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 13   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 14   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 15   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 16   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 17   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 18   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 19   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 20   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 21   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 22   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 23   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 24   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 25   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 26   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 27   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 28   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 29   ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# ..                                      ...         ...  ...   ...     ...
# 770  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 771  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 772  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 773  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 774  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 775  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 776  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 777  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 778  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 779  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 780  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 781  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 782  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 783  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 784  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 785  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 786  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 787  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 788  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 789  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 790  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 791  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 792  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 793  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 794  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 795  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 796  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 797  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 798  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
# 799  ../Data/{}_data_ACSF_expand_PCA.pickle          32  128     2       3
#
#      layer2  factor  ...  train_type_7  val_type_0  val_type_1  val_type_2  \
# 0         2       2  ...           NaN    0.110294         NaN         NaN
# 1         2       2  ...           NaN   -0.078483         NaN         NaN
# 2         2       2  ...           NaN    0.016523         NaN         NaN
# 3         2       2  ...           NaN   -0.119841         NaN         NaN
# 4         2       2  ...           NaN   -0.310461         NaN         NaN
# 5         2       2  ...           NaN   -0.351942         NaN         NaN
# 6         2       2  ...           NaN   -0.377680         NaN         NaN
# 7         2       2  ...           NaN   -0.400741         NaN         NaN
# 8         2       2  ...           NaN   -0.446105         NaN         NaN
# 9         2       2  ...           NaN   -0.472565         NaN         NaN
# 10        2       2  ...           NaN   -0.485628         NaN         NaN
# 11        2       2  ...           NaN   -0.475885         NaN         NaN
# 12        2       2  ...           NaN   -0.532896         NaN         NaN
# 13        2       2  ...           NaN   -0.568122         NaN         NaN
# 14        2       2  ...           NaN   -0.401472         NaN         NaN
# 15        2       2  ...           NaN   -0.590771         NaN         NaN
# 16        2       2  ...           NaN   -0.611770         NaN         NaN
# 17        2       2  ...           NaN   -0.503030         NaN         NaN
# 18        2       2  ...           NaN   -0.634545         NaN         NaN
# 19        2       2  ...           NaN   -0.663714         NaN         NaN
# 20        2       2  ...           NaN   -0.667320         NaN         NaN
# 21        2       2  ...           NaN   -0.690384         NaN         NaN
# 22        2       2  ...           NaN   -0.623539         NaN         NaN
# 23        2       2  ...           NaN   -0.670853         NaN         NaN
# 24        2       2  ...           NaN   -0.726969         NaN         NaN
# 25        2       2  ...           NaN   -0.677422         NaN         NaN
# 26        2       2  ...           NaN   -0.746948         NaN         NaN
# 27        2       2  ...           NaN   -0.733131         NaN         NaN
# 28        2       2  ...           NaN   -0.704081         NaN         NaN
# 29        2       2  ...           NaN   -0.728231         NaN         NaN
# ..      ...     ...  ...           ...         ...         ...         ...
# 770       2       2  ...           NaN         NaN         NaN   -1.651853
# 771       2       2  ...           NaN         NaN         NaN   -1.660734
# 772       2       2  ...           NaN         NaN         NaN   -1.678902
# 773       2       2  ...           NaN         NaN         NaN   -1.697685
# 774       2       2  ...           NaN         NaN         NaN   -1.710590
# 775       2       2  ...           NaN         NaN         NaN   -1.728759
# 776       2       2  ...           NaN         NaN         NaN   -1.726519
# 777       2       2  ...           NaN         NaN         NaN   -1.730551
# 778       2       2  ...           NaN         NaN         NaN   -1.723953
# 779       2       2  ...           NaN         NaN         NaN   -1.753596
# 780       2       2  ...           NaN         NaN         NaN   -1.723784
# 781       2       2  ...           NaN         NaN         NaN   -1.783729
# 782       2       2  ...           NaN         NaN         NaN   -1.763417
# 783       2       2  ...           NaN         NaN         NaN   -1.795581
# 784       2       2  ...           NaN         NaN         NaN   -1.811382
# 785       2       2  ...           NaN         NaN         NaN   -1.807617
# 786       2       2  ...           NaN         NaN         NaN   -1.777830
# 787       2       2  ...           NaN         NaN         NaN   -1.818938
# 788       2       2  ...           NaN         NaN         NaN   -1.836987
# 789       2       2  ...           NaN         NaN         NaN   -1.828137
# 790       2       2  ...           NaN         NaN         NaN   -1.834025
# 791       2       2  ...           NaN         NaN         NaN   -1.831302
# 792       2       2  ...           NaN         NaN         NaN   -1.854868
# 793       2       2  ...           NaN         NaN         NaN   -1.858352
# 794       2       2  ...           NaN         NaN         NaN   -1.856350
# 795       2       2  ...           NaN         NaN         NaN   -1.831761
# 796       2       2  ...           NaN         NaN         NaN   -1.869993
# 797       2       2  ...           NaN         NaN         NaN   -1.873052
# 798       2       2  ...           NaN         NaN         NaN   -1.862154
# 799       2       2  ...           NaN         NaN         NaN   -1.854450
#
#      val_type_3  val_type_4  val_type_5  val_type_6  val_type_7  \
# 0           NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN
# 5           NaN         NaN         NaN         NaN         NaN
# 6           NaN         NaN         NaN         NaN         NaN
# 7           NaN         NaN         NaN         NaN         NaN
# 8           NaN         NaN         NaN         NaN         NaN
# 9           NaN         NaN         NaN         NaN         NaN
# 10          NaN         NaN         NaN         NaN         NaN
# 11          NaN         NaN         NaN         NaN         NaN
# 12          NaN         NaN         NaN         NaN         NaN
# 13          NaN         NaN         NaN         NaN         NaN
# 14          NaN         NaN         NaN         NaN         NaN
# 15          NaN         NaN         NaN         NaN         NaN
# 16          NaN         NaN         NaN         NaN         NaN
# 17          NaN         NaN         NaN         NaN         NaN
# 18          NaN         NaN         NaN         NaN         NaN
# 19          NaN         NaN         NaN         NaN         NaN
# 20          NaN         NaN         NaN         NaN         NaN
# 21          NaN         NaN         NaN         NaN         NaN
# 22          NaN         NaN         NaN         NaN         NaN
# 23          NaN         NaN         NaN         NaN         NaN
# 24          NaN         NaN         NaN         NaN         NaN
# 25          NaN         NaN         NaN         NaN         NaN
# 26          NaN         NaN         NaN         NaN         NaN
# 27          NaN         NaN         NaN         NaN         NaN
# 28          NaN         NaN         NaN         NaN         NaN
# 29          NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...
# 770         NaN         NaN         NaN         NaN         NaN
# 771         NaN         NaN         NaN         NaN         NaN
# 772         NaN         NaN         NaN         NaN         NaN
# 773         NaN         NaN         NaN         NaN         NaN
# 774         NaN         NaN         NaN         NaN         NaN
# 775         NaN         NaN         NaN         NaN         NaN
# 776         NaN         NaN         NaN         NaN         NaN
# 777         NaN         NaN         NaN         NaN         NaN
# 778         NaN         NaN         NaN         NaN         NaN
# 779         NaN         NaN         NaN         NaN         NaN
# 780         NaN         NaN         NaN         NaN         NaN
# 781         NaN         NaN         NaN         NaN         NaN
# 782         NaN         NaN         NaN         NaN         NaN
# 783         NaN         NaN         NaN         NaN         NaN
# 784         NaN         NaN         NaN         NaN         NaN
# 785         NaN         NaN         NaN         NaN         NaN
# 786         NaN         NaN         NaN         NaN         NaN
# 787         NaN         NaN         NaN         NaN         NaN
# 788         NaN         NaN         NaN         NaN         NaN
# 789         NaN         NaN         NaN         NaN         NaN
# 790         NaN         NaN         NaN         NaN         NaN
# 791         NaN         NaN         NaN         NaN         NaN
# 792         NaN         NaN         NaN         NaN         NaN
# 793         NaN         NaN         NaN         NaN         NaN
# 794         NaN         NaN         NaN         NaN         NaN
# 795         NaN         NaN         NaN         NaN         NaN
# 796         NaN         NaN         NaN         NaN         NaN
# 797         NaN         NaN         NaN         NaN         NaN
# 798         NaN         NaN         NaN         NaN         NaN
# 799         NaN         NaN         NaN         NaN         NaN
#
#                                                                                                                                                                   file_name
# 0    results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 1    results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 2    results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 3    results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 4    results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 5    results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 6    results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 7    results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 8    results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 9    results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 10   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 11   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 12   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 13   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 14   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 15   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 16   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 17   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 18   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 19   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 20   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 21   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 22   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 23   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 24   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 25   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 26   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 27   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 28   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# 29   results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_0_start.csv
# ..                                                                                                                                                                      ...
# 770  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 771  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 772  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 773  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 774  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 775  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 776  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 777  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 778  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 779  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 780  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 781  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 782  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 783  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 784  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 785  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 786  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 787  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 788  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 789  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 790  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 791  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 792  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 793  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 794  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 795  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 796  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 797  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 798  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
# 799  results_False_<class 'functions_refactor.NNConv_block'>_<class 'functions_refactor.cat3HeadPool_type'>__data_ACSF_expand_PCA.pickle_32_128_2_3_2_2_50_type_2_start.csv
#
# [800 rows x 28 columns]

# %%
df[['val_type_'+str(i) for i in range(8)]].min()
# Out:
# val_type_0   -0.883418
# val_type_1   -1.465249
# val_type_2   -1.873052
# val_type_3   -2.640546
# val_type_4   -2.496475
# val_type_5   -1.442985
# val_type_6         NaN
# val_type_7   -2.566730
# dtype: float64

# %%
pd.isnull(df['type']).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/pytorch/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-d1bba53b2797> in <module>
# ----> 1 pd.isnull(df['type']).sum()
#
# ~/anaconda3/envs/pytorch/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/envs/pytorch/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type'

# %%
df['type'] = df.file_name.str.split('type_',expand=True)[1].str[0]

# %%
df = df.loc[np.logical_not(df.type.isnull())]

# %%
gb = df.groupby(['type','file_name'])

# %%
for name,group in gb:
    group[['train_type_'+name[0],'val_type_'+name[0]]].reset_index(drop=True).plot(title=name[1])
    plt.show()
