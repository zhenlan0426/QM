# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
pd.set_option('max_colwidth', 800)

# %%
results = [file for file in os.listdir('/home/will/Downloads/0807_alltype/0807/') if 'result' in file]
df_list = []
for result in results:
    df = pd.read_csv('/home/will/Downloads/0807_alltype/0807/'+result,na_values=0)
    df['file_name'] = result
    df_list.append(df)
df = pd.concat(df_list,ignore_index=True)#.fillna(1e4)

# %%
df
# Out:
#                                                        0  \
# 0    <class 'functions_refactor.feedforwardHead_Update'>
# 1    <class 'functions_refactor.feedforwardHead_Update'>
# 2    <class 'functions_refactor.feedforwardHead_Update'>
# 3    <class 'functions_refactor.feedforwardHead_Update'>
# 4    <class 'functions_refactor.feedforwardHead_Update'>
# 5    <class 'functions_refactor.feedforwardHead_Update'>
# 6    <class 'functions_refactor.feedforwardHead_Update'>
# 7    <class 'functions_refactor.feedforwardHead_Update'>
# 8    <class 'functions_refactor.feedforwardHead_Update'>
# 9    <class 'functions_refactor.feedforwardHead_Update'>
# 10   <class 'functions_refactor.feedforwardHead_Update'>
# 11   <class 'functions_refactor.feedforwardHead_Update'>
# 12   <class 'functions_refactor.feedforwardHead_Update'>
# 13   <class 'functions_refactor.feedforwardHead_Update'>
# 14   <class 'functions_refactor.feedforwardHead_Update'>
# 15   <class 'functions_refactor.feedforwardHead_Update'>
# 16   <class 'functions_refactor.feedforwardHead_Update'>
# 17   <class 'functions_refactor.feedforwardHead_Update'>
# 18   <class 'functions_refactor.feedforwardHead_Update'>
# 19   <class 'functions_refactor.feedforwardHead_Update'>
# 20   <class 'functions_refactor.feedforwardHead_Update'>
# 21   <class 'functions_refactor.feedforwardHead_Update'>
# 22   <class 'functions_refactor.feedforwardHead_Update'>
# 23   <class 'functions_refactor.feedforwardHead_Update'>
# 24   <class 'functions_refactor.feedforwardHead_Update'>
# 25   <class 'functions_refactor.feedforwardHead_Update'>
# 26   <class 'functions_refactor.feedforwardHead_Update'>
# 27   <class 'functions_refactor.feedforwardHead_Update'>
# 28   <class 'functions_refactor.feedforwardHead_Update'>
# 29   <class 'functions_refactor.feedforwardHead_Update'>
# ..                                                   ...
# 120       <class 'functions_refactor.SimplyInteraction'>
# 121       <class 'functions_refactor.SimplyInteraction'>
# 122       <class 'functions_refactor.SimplyInteraction'>
# 123       <class 'functions_refactor.SimplyInteraction'>
# 124       <class 'functions_refactor.SimplyInteraction'>
# 125       <class 'functions_refactor.SimplyInteraction'>
# 126       <class 'functions_refactor.SimplyInteraction'>
# 127       <class 'functions_refactor.SimplyInteraction'>
# 128       <class 'functions_refactor.SimplyInteraction'>
# 129       <class 'functions_refactor.SimplyInteraction'>
# 130       <class 'functions_refactor.SimplyInteraction'>
# 131       <class 'functions_refactor.SimplyInteraction'>
# 132       <class 'functions_refactor.SimplyInteraction'>
# 133       <class 'functions_refactor.SimplyInteraction'>
# 134       <class 'functions_refactor.SimplyInteraction'>
# 135       <class 'functions_refactor.SimplyInteraction'>
# 136       <class 'functions_refactor.SimplyInteraction'>
# 137       <class 'functions_refactor.SimplyInteraction'>
# 138       <class 'functions_refactor.SimplyInteraction'>
# 139       <class 'functions_refactor.SimplyInteraction'>
# 140       <class 'functions_refactor.SimplyInteraction'>
# 141       <class 'functions_refactor.SimplyInteraction'>
# 142       <class 'functions_refactor.SimplyInteraction'>
# 143       <class 'functions_refactor.SimplyInteraction'>
# 144       <class 'functions_refactor.SimplyInteraction'>
# 145       <class 'functions_refactor.SimplyInteraction'>
# 146       <class 'functions_refactor.SimplyInteraction'>
# 147       <class 'functions_refactor.SimplyInteraction'>
# 148       <class 'functions_refactor.SimplyInteraction'>
# 149       <class 'functions_refactor.SimplyInteraction'>
#
#                                                        1    2      3  \
# 0    ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 1    ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 2    ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 3    ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 4    ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 5    ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 6    ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 7    ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 8    ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 9    ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 10   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 11   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 12   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 13   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 14   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 15   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 16   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 17   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 18   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 19   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 20   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 21   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 22   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 23   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 24   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 25   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 26   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 27   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 28   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# 29   ../Data/{}_data_ACSF_SOAP_atomInfo_otherInfo.pickle  512  False
# ..                                                   ...  ...    ...
# 120     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 121     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 122     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 123     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 124     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 125     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 126     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 127     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 128     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 129     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 130     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 131     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 132     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 133     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 134     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 135     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 136     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 137     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 138     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 139     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 140     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 141     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 142     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 143     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 144     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 145     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 146     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 147     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 148     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
# 149     ../Data/{}_data_SOAP_expand_PCA_otherInfo.pickle  256   True
#
#             4  5  6  7    8      9  ...  train_type_7  val_type_0  val_type_1  \
# 0    0.345376  3  3  3  add   True  ...     -0.910269    0.871069    0.540115
# 1    0.345376  3  3  3  add   True  ...     -1.316327    1.078233    0.417936
# 2    0.345376  3  3  3  add   True  ...     -1.492686    0.465647   -0.013572
# 3    0.345376  3  3  3  add   True  ...     -1.633940    0.063063   -0.138040
# 4    0.345376  3  3  3  add   True  ...     -1.734885    0.654557   -0.116136
# 5    0.345376  3  3  3  add   True  ...     -1.816789   -0.069456   -0.383473
# 6    0.345376  3  3  3  add   True  ...     -1.887544   -0.280574   -0.774257
# 7    0.345376  3  3  3  add   True  ...     -1.945185   -0.026556   -0.618164
# 8    0.345376  3  3  3  add   True  ...     -1.968738   -0.262556   -0.720556
# 9    0.345376  3  3  3  add   True  ...     -2.022240    0.339808   -0.599557
# 10   0.345376  3  3  3  add   True  ...     -2.075192    0.440880   -0.346187
# 11   0.345376  3  3  3  add   True  ...     -2.094375   -0.471321   -0.839173
# 12   0.345376  3  3  3  add   True  ...     -2.132358    0.134366   -0.757466
# 13   0.345376  3  3  3  add   True  ...     -2.153948   -0.536862   -0.994066
# 14   0.345376  3  3  3  add   True  ...     -2.165977   -0.427758   -0.623371
# 15   0.345376  3  3  3  add   True  ...     -2.222123   -0.474645   -0.695441
# 16   0.345376  3  3  3  add   True  ...     -2.233531   -0.620527   -0.942664
# 17   0.345376  3  3  3  add   True  ...     -2.271967   -0.499717   -1.038229
# 18   0.345376  3  3  3  add   True  ...     -2.299554   -0.499036   -1.048203
# 19   0.345376  3  3  3  add   True  ...     -2.327197   -0.720998   -1.138698
# 20   0.345376  3  3  3  add   True  ...     -2.295750   -0.268054   -0.624111
# 21   0.345376  3  3  3  add   True  ...     -2.345810   -0.460654   -1.010027
# 126   -1.147788   -1.402377   -2.127302   -0.922478   -1.776138   -2.256554
# 127   -1.377978   -2.284158   -2.129472   -1.212841   -2.010980   -2.428937
# 128   -1.474123   -2.252923   -2.190954   -1.263936   -2.168098   -2.383583
# 129   -1.464859   -2.365437   -2.199147   -1.263801   -2.037085   -2.481584
# 130   -1.468432   -1.986426   -2.256634   -1.268805   -2.071118   -2.481083
# 131   -1.485972   -1.943838   -2.288433   -1.252533   -2.119608   -2.396902
# 132   -1.470844   -2.260174   -2.348632   -1.266224   -2.188997   -2.410673
# 133   -1.477235   -2.362892   -2.286000   -1.282208   -1.953904   -2.527723
# 134   -1.489695   -2.342013   -2.277617   -1.295156   -2.089524   -2.459568
# 135   -1.473052   -2.367500   -2.288468   -1.292211   -2.194821   -2.513678
# 136   -1.463983   -2.332125   -2.314848   -1.273706   -2.195190   -2.483020
# 137   -1.038717   -2.039399   -2.100574   -0.953070   -1.729949   -2.125178
# 138   -1.534003   -2.390529   -2.344189   -1.330866   -2.197248   -2.535352
# 139   -1.495287   -2.292258   -2.243180   -1.317311   -2.176693   -2.423552
# 140   -1.511343   -2.427396   -2.339260   -1.314984   -2.181724   -2.536628
# 141   -1.516696   -2.017260   -2.350129   -1.332846   -2.068982   -2.489388
# 142   -1.537506   -2.446973   -2.325862   -1.335743   -2.175870   -2.535218
# 143   -1.489300   -2.364848   -2.367237   -1.313389   -2.110174   -2.510833
# 144   -1.551283   -2.423321   -2.332008   -1.357980   -2.237568   -2.578717
# 145   -1.551047   -2.219034   -2.351723   -1.358430   -2.252228   -2.575831
# 146   -1.533790   -2.442863   -2.410582   -1.348627   -2.241850   -2.553089
# 147   -1.298646   -2.243346   -2.245257   -1.060730   -1.962173   -2.434443
# 148   -1.577635   -2.427605   -2.369960   -1.354025   -2.294071   -2.583725
# 149   -1.549906   -2.391867   -2.359097   -1.369049   -1.998672   -2.561263
#
#                                                                                                                                                 file_name
# 0    results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 1    results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 2    results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 3    results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 4    results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 5    results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 6    results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 7    results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 8    results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 9    results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 10   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 11   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 12   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 13   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 14   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 15   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 16   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 17   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 18   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 19   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 20   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 21   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 22   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 23   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 24   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 25   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 26   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 27   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 28   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 29   results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# ..                                                                                                                                                    ...
# 120         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 121         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 122         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 123         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 124         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 125         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 126         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 127         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 128         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 129         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 130         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 131         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 132         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 133         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 134         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 135         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 136         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 137         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 138         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 139         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 140         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 141         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 142         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 143         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 144         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 145         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 146         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 147         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 148         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
# 149         results_<class 'functions_refactor.SimplyInteraction'>__data_SOAP_expand_PCA_otherInfo.pickle_256_True_1.9566978325242024_4_4_4_max_False.csv
#
# [150 rows x 28 columns]

# %%
df[['val_type_'+str(i) for i in range(8)]].min()
# Out:
# val_type_0   -1.173966
# val_type_1   -1.774169
# val_type_2   -1.889927
# val_type_3   -2.657624
# val_type_4   -2.662327
# val_type_5   -1.701018
# val_type_6   -2.472784
# val_type_7   -2.720488
# dtype: float64

# %%
temp_index = np.nanargmin(df[['val_type_'+str(i) for i in range(8)]].values,0)

# %%
df.loc[temp_index,['val_type_'+str(i) for i in range(8)]+['file_name']]
# Out:
#     val_type_0  val_type_1  val_type_2  val_type_3  val_type_4  val_type_5  \
# 99   -1.173966   -1.696537   -1.889927   -2.426729   -2.662327   -1.701018
# 48   -1.110940   -1.774169   -1.849995   -2.532607   -2.577980   -1.676669
# 99   -1.173966   -1.696537   -1.889927   -2.426729   -2.662327   -1.701018
# 44   -1.092068   -1.654160   -1.813150   -2.657624   -2.565618   -1.660098
# 99   -1.173966   -1.696537   -1.889927   -2.426729   -2.662327   -1.701018
# 99   -1.173966   -1.696537   -1.889927   -2.426729   -2.662327   -1.701018
# 99   -1.173966   -1.696537   -1.889927   -2.426729   -2.662327   -1.701018
# 49   -1.135307   -1.689381   -1.856715   -2.468422   -2.581019   -1.671804
#
#     val_type_6  val_type_7  \
# 99   -2.472784   -2.717787
# 48   -2.421706   -2.708501
# 99   -2.472784   -2.717787
# 44   -2.389532   -2.688493
# 99   -2.472784   -2.717787
# 99   -2.472784   -2.717787
# 99   -2.472784   -2.717787
# 49   -2.399719   -2.720488
#
#                                                                                                                                                file_name
# 99        results_<class 'functions_refactor.SimplyInteraction'>__data_ACSF_expand_PCA_otherInfo.pickle_256_False_0.1765199819215488_4_4_2_max_False.csv
# 48  results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 99        results_<class 'functions_refactor.SimplyInteraction'>__data_ACSF_expand_PCA_otherInfo.pickle_256_False_0.1765199819215488_4_4_2_max_False.csv
# 44  results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv
# 99        results_<class 'functions_refactor.SimplyInteraction'>__data_ACSF_expand_PCA_otherInfo.pickle_256_False_0.1765199819215488_4_4_2_max_False.csv
# 99        results_<class 'functions_refactor.SimplyInteraction'>__data_ACSF_expand_PCA_otherInfo.pickle_256_False_0.1765199819215488_4_4_2_max_False.csv
# 99        results_<class 'functions_refactor.SimplyInteraction'>__data_ACSF_expand_PCA_otherInfo.pickle_256_False_0.1765199819215488_4_4_2_max_False.csv
# 49  results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_SOAP_atomInfo_otherInfo.pickle_512_False_0.345375661702555_3_3_3_add_True.csv

# %%
# head,data,dim,logLoss,weight,layer1,layer2,factor

# %%
def get_bestScore_forTypes(df,file_name):
    df_temp = df.loc[df.file_name.str.contains(file_name)]
    return df_temp[['val_type_'+str(i) for i in range(8)]].min()

# %%
best_score_model_i = get_bestScore_forTypes(df,"functions_refactor.SimplyInteraction'>__data_ACSF_expand_PCA_otherInfo.pickle_256_False_0.1765199819215488_4_4_2_max_False")

# %%
best_score_model_i
# Out:
# val_type_0   -1.173966
# val_type_1   -1.705142
# val_type_2   -1.889927
# val_type_3   -2.506721
# val_type_4   -2.662327
# val_type_5   -1.701018
# val_type_6   -2.472784
# val_type_7   -2.717787
# dtype: float64

# %%
best_score_model_i.mean()
# Out:
# -2.103709171104253

# %%
for i in range(8):
    for f in df.file_name.unique():
        df_temp = df.loc[df.file_name==f]
        print('\n'+f)
        df_temp.loc[:,['train_type_'+str(i),'val_type_'+str(i)]].plot()
        plt.show()
# Out:
# results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_expand_PCA_otherInfo.pickle_768_False_0.2521240016323349_3_4_2_max_False.csv
# results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_expand_PCA_otherInfo.pickle_768_False_0.2521240016323349_3_4_2_max_False.csv
# results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_expand_PCA_otherInfo.pickle_768_False_0.2521240016323349_3_4_2_max_False.csv
# results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_expand_PCA_otherInfo.pickle_768_False_0.2521240016323349_3_4_2_max_False.csv
# results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_expand_PCA_otherInfo.pickle_768_False_0.2521240016323349_3_4_2_max_False.csv
# results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_expand_PCA_otherInfo.pickle_768_False_0.2521240016323349_3_4_2_max_False.csv
# results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_expand_PCA_otherInfo.pickle_768_False_0.2521240016323349_3_4_2_max_False.csv
# results_<class 'functions_refactor.feedforwardHead_Update'>__data_ACSF_expand_PCA_otherInfo.pickle_768_False_0.2521240016323349_3_4_2_max_False.csv
