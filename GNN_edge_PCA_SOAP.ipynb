# %%
import pickle
import torch
from torch_geometric.data import Data,DataLoader
from functions_refactor import *
from pytorch_util import *
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
# model parameters
reuse = False
block = MEGNet_block
head = feedforwardHead_Update
data = '../Data/{}_data_SOAP_expand_PCA.pickle'
batch_size = 32
dim = 128
epochs = 50
clip = 0.4
layer1 = 3
layer2 = 3
factor = 2
lr = 1e-4

# %% [markdown]
# #### train base

# %%
train_dl,val_dl = get_data(data,batch_size)

model = GNN_edgeUpdate(reuse,block,head,dim,layer1,layer2,factor,**data_dict[data]).to('cuda:0')

paras = trainable_parameter(model)
opt = Adam(paras,lr=lr)
scheduler = ReduceLROnPlateau(opt, 'min',factor=0.5,patience=5)

model,train_loss_list,val_loss_list,bestWeight = train_type(opt,model,epochs,train_dl,val_dl,paras,clip,scheduler=scheduler)
# Out:
# epoch:0, train_loss: +0.422, val_loss: +0.025,
# train_vector: +4.28|+1.05|+0.18|-0.36|-0.56|+0.20|-0.51|-0.91,
# val_vector  : +4.01|+0.35|-0.22|-0.66|-0.99|-0.11|-0.99|-1.18
#
# epoch:1, train_loss: -0.219, val_loss: -0.640,
# train_vector: +2.65|+0.31|-0.28|-0.90|-1.05|-0.16|-1.00|-1.31,
# val_vector  : +0.81|-0.12|-0.46|-1.13|-1.23|-0.31|-1.23|-1.47
#
# epoch:2, train_loss: -0.607, val_loss: -0.739,
# train_vector: +0.89|+0.08|-0.47|-1.16|-1.25|-0.31|-1.17|-1.49,
# val_vector  : +0.83|+0.08|-0.60|-1.55|-1.39|-0.42|-1.32|-1.57
#
# epoch:3, train_loss: -0.727, val_loss: -0.861,
# train_vector: +0.80|-0.07|-0.58|-1.30|-1.38|-0.40|-1.28|-1.60,
# val_vector  : +0.59|-0.21|-0.70|-1.44|-1.50|-0.49|-1.46|-1.68
#
# epoch:4, train_loss: -0.807, val_loss: -1.023,
# train_vector: +0.76|-0.16|-0.66|-1.40|-1.48|-0.47|-1.36|-1.68,
# val_vector  : +0.23|-0.54|-0.76|-1.68|-1.63|-0.57|-1.48|-1.75
#
# epoch:5, train_loss: -0.872, val_loss: -0.984,
# train_vector: +0.70|-0.22|-0.72|-1.49|-1.55|-0.53|-1.42|-1.75,
# val_vector  : +0.11|-0.04|-0.81|-1.60|-1.63|-0.61|-1.51|-1.78
#
# epoch:6, train_loss: -0.931, val_loss: -0.978,
# train_vector: +0.65|-0.28|-0.78|-1.56|-1.61|-0.58|-1.47|-1.82,
# val_vector  : +0.07|-0.20|-0.86|-1.44|-1.55|-0.64|-1.40|-1.81
#
# epoch:7, train_loss: -0.984, val_loss: -0.958,
# train_vector: +0.59|-0.37|-0.82|-1.62|-1.66|-0.61|-1.51|-1.86,
# val_vector  : +0.32|-0.09|-0.89|-1.61|-1.50|-0.66|-1.40|-1.83
#
# epoch:8, train_loss: -1.020, val_loss: -1.109,
# train_vector: +0.53|-0.39|-0.86|-1.64|-1.70|-0.65|-1.55|-1.90,
# val_vector  : +0.39|-0.74|-0.92|-1.60|-1.77|-0.71|-1.63|-1.89
#
# epoch:9, train_loss: -1.075, val_loss: -1.132,
# train_vector: +0.42|-0.46|-0.90|-1.70|-1.75|-0.68|-1.59|-1.95,
# val_vector  : +0.11|-0.23|-0.92|-1.89|-1.76|-0.76|-1.64|-1.96
#
# epoch:10, train_loss: -1.115, val_loss: -1.105,
# train_vector: +0.37|-0.51|-0.93|-1.74|-1.79|-0.71|-1.62|-1.99,
# val_vector  : +0.26|-0.06|-1.00|-2.02|-1.64|-0.78|-1.61|-1.99
#
# epoch:11, train_loss: -1.142, val_loss: -1.280,
# train_vector: +0.31|-0.51|-0.96|-1.77|-1.82|-0.73|-1.64|-2.02,
# val_vector  : +0.08|-0.85|-1.04|-2.00|-1.85|-0.79|-1.80|-2.00
#
# epoch:12, train_loss: -1.171, val_loss: -1.152,
# train_vector: +0.29|-0.53|-0.98|-1.81|-1.85|-0.76|-1.67|-2.05,
# val_vector  : +0.46|-0.30|-1.06|-2.03|-1.75|-0.81|-1.74|-2.00
#
# epoch:13, train_loss: -1.208, val_loss: -1.207,
# train_vector: +0.25|-0.60|-1.01|-1.84|-1.89|-0.78|-1.71|-2.08,
# val_vector  : +0.55|-0.67|-1.09|-1.83|-1.96|-0.84|-1.77|-2.04
#
# epoch:14, train_loss: -1.234, val_loss: -1.323,
# train_vector: +0.20|-0.63|-1.03|-1.85|-1.92|-0.80|-1.73|-2.11,
# val_vector  : -0.05|-0.78|-1.08|-1.99|-1.97|-0.86|-1.79|-2.06
#
# epoch:15, train_loss: -1.259, val_loss: -1.183,
# train_vector: +0.14|-0.65|-1.05|-1.88|-1.94|-0.82|-1.74|-2.13,
# val_vector  : +0.13|-0.39|-1.07|-1.98|-1.60|-0.86|-1.77|-1.93
#
# epoch:16, train_loss: -1.284, val_loss: -1.312,
# train_vector: +0.10|-0.65|-1.08|-1.91|-1.96|-0.84|-1.77|-2.16,
# val_vector  : +0.34|-0.75|-1.15|-2.11|-1.92|-0.90|-1.87|-2.13
#
# epoch:17, train_loss: -1.303, val_loss: -1.239,
# train_vector: +0.08|-0.68|-1.09|-1.92|-1.98|-0.86|-1.79|-2.18,
# val_vector  : +0.41|-0.28|-1.16|-2.09|-1.90|-0.91|-1.88|-2.10
#
# epoch:18, train_loss: -1.327, val_loss: -1.307,
# train_vector: +0.05|-0.72|-1.11|-1.95|-2.00|-0.88|-1.81|-2.20,
# val_vector  : +0.25|-0.79|-1.19|-1.87|-1.89|-0.94|-1.90|-2.14
#
# epoch:19, train_loss: -1.346, val_loss: -1.397,
# train_vector: +0.03|-0.73|-1.13|-1.96|-2.03|-0.89|-1.82|-2.22,
# val_vector  : -0.23|-0.80|-1.13|-2.07|-1.99|-0.90|-1.93|-2.13
#
# epoch:20, train_loss: -1.366, val_loss: -1.405,
# train_vector: -0.01|-0.75|-1.15|-1.98|-2.04|-0.91|-1.84|-2.25,
# val_vector  : -0.04|-0.77|-1.20|-2.15|-2.01|-0.95|-1.94|-2.19
#
# epoch:21, train_loss: -1.378, val_loss: -1.447,
# train_vector: -0.01|-0.75|-1.16|-2.00|-2.06|-0.92|-1.86|-2.26,
# val_vector  : -0.17|-0.88|-1.22|-2.19|-2.02|-0.98|-1.91|-2.20
#
# epoch:22, train_loss: -1.392, val_loss: -1.237,
# train_vector: -0.03|-0.75|-1.17|-2.03|-2.07|-0.94|-1.87|-2.28,
# val_vector  : +0.22|+0.22|-1.22|-1.95|-2.04|-0.98|-1.95|-2.21
#
# epoch:23, train_loss: -1.409, val_loss: -1.365,
# train_vector: -0.06|-0.79|-1.19|-2.02|-2.10|-0.95|-1.88|-2.29,
# val_vector  : -0.28|-0.19|-1.25|-1.99|-2.06|-1.00|-1.97|-2.19
#
# epoch:24, train_loss: -1.423, val_loss: -1.471,
# train_vector: -0.06|-0.80|-1.20|-2.05|-2.11|-0.96|-1.90|-2.30,
# val_vector  : -0.18|-1.06|-1.24|-2.10|-2.06|-1.01|-1.90|-2.21
#
# epoch:25, train_loss: -1.444, val_loss: -1.443,
# train_vector: -0.10|-0.84|-1.22|-2.06|-2.12|-0.97|-1.91|-2.33,
# val_vector  : -0.02|-0.88|-1.28|-2.12|-2.08|-0.99|-1.95|-2.23
#
# epoch:26, train_loss: -1.459, val_loss: -1.284,
# train_vector: -0.11|-0.87|-1.23|-2.06|-2.15|-0.98|-1.93|-2.34,
# val_vector  : +0.63|-0.34|-1.26|-2.21|-1.99|-1.01|-1.91|-2.19
#
# epoch:27, train_loss: -1.467, val_loss: -1.425,
# train_vector: -0.13|-0.86|-1.24|-2.07|-2.15|-0.99|-1.94|-2.36,
# val_vector  : +0.36|-0.78|-1.30|-2.25|-2.09|-1.04|-2.01|-2.28
#
# epoch:28, train_loss: -1.486, val_loss: -1.480,
# train_vector: -0.14|-0.91|-1.25|-2.09|-2.17|-1.00|-1.95|-2.37,
# val_vector  : +0.06|-0.93|-1.27|-2.28|-2.06|-1.04|-2.04|-2.29
#
# epoch:29, train_loss: -1.495, val_loss: -1.452,
# train_vector: -0.15|-0.90|-1.26|-2.10|-2.19|-1.01|-1.96|-2.39,
# val_vector  : +0.16|-0.60|-1.32|-2.30|-2.16|-1.06|-2.05|-2.29
#
# epoch:30, train_loss: -1.503, val_loss: -1.508,
# train_vector: -0.15|-0.89|-1.27|-2.12|-2.20|-1.03|-1.97|-2.40,
# val_vector  : -0.14|-0.87|-1.29|-2.23|-2.13|-1.06|-2.04|-2.30
#
# epoch:31, train_loss: -1.517, val_loss: -1.552,
# train_vector: -0.17|-0.91|-1.28|-2.14|-2.20|-1.03|-1.98|-2.41,
# val_vector  : -0.29|-1.10|-1.28|-2.15|-2.16|-1.07|-2.10|-2.27
#
# epoch:32, train_loss: -1.530, val_loss: -1.586,
# train_vector: -0.19|-0.93|-1.29|-2.15|-2.22|-1.04|-1.99|-2.42,
# val_vector  : -0.38|-1.17|-1.32|-2.36|-2.04|-1.05|-2.02|-2.35
#
# epoch:33, train_loss: -1.541, val_loss: -1.467,
# train_vector: -0.19|-0.95|-1.31|-2.15|-2.23|-1.05|-2.00|-2.45,
# val_vector  : +0.19|-0.87|-1.30|-2.25|-2.15|-1.08|-2.03|-2.24
#
# epoch:34, train_loss: -1.546, val_loss: -1.506,
# train_vector: -0.20|-0.94|-1.31|-2.16|-2.24|-1.06|-2.01|-2.45,
# val_vector  : -0.22|-0.65|-1.34|-2.30|-2.14|-1.09|-2.02|-2.29
#
# epoch:35, train_loss: -1.556, val_loss: -1.514,
# train_vector: -0.20|-0.95|-1.32|-2.17|-2.25|-1.07|-2.02|-2.46,
# val_vector  : -0.44|-0.15|-1.36|-2.36|-2.22|-1.11|-2.09|-2.37
#
# epoch:36, train_loss: -1.566, val_loss: -1.486,
# train_vector: -0.21|-0.96|-1.33|-2.17|-2.27|-1.08|-2.03|-2.48,
# val_vector  : -0.12|-0.37|-1.36|-2.35|-2.19|-1.08|-2.07|-2.35
#
# epoch:37, train_loss: -1.584, val_loss: -1.600,
# train_vector: -0.23|-1.02|-1.34|-2.19|-2.27|-1.08|-2.05|-2.49,
# val_vector  : -0.24|-1.10|-1.38|-2.32|-2.17|-1.12|-2.11|-2.37
#
# epoch:38, train_loss: -1.588, val_loss: -1.636,
# train_vector: -0.24|-0.99|-1.35|-2.19|-2.29|-1.09|-2.05|-2.50,
# val_vector  : -0.45|-1.27|-1.38|-2.23|-2.21|-1.12|-2.10|-2.33
#
# epoch:39, train_loss: -1.596, val_loss: -1.488,
# train_vector: -0.25|-1.01|-1.36|-2.20|-2.29|-1.10|-2.06|-2.51,
# val_vector  : +0.05|-0.72|-1.38|-2.20|-2.11|-1.11|-2.10|-2.33
#
# epoch:40, train_loss: -1.609, val_loss: -1.480,
# train_vector: -0.26|-1.03|-1.36|-2.23|-2.31|-1.11|-2.07|-2.51,
# val_vector  : +0.17|-0.60|-1.35|-2.24|-2.21|-1.14|-2.13|-2.35
#
# epoch:41, train_loss: -1.615, val_loss: -1.655,
# train_vector: -0.27|-1.02|-1.37|-2.23|-2.32|-1.11|-2.08|-2.53,
# val_vector  : -0.37|-1.21|-1.40|-2.34|-2.24|-1.14|-2.17|-2.38
#
# epoch:42, train_loss: -1.623, val_loss: -1.652,
# train_vector: -0.27|-1.03|-1.37|-2.24|-2.33|-1.12|-2.08|-2.53,
# val_vector  : -0.44|-1.23|-1.39|-2.29|-2.31|-1.16|-2.00|-2.40
#
# epoch:43, train_loss: -1.628, val_loss: -1.531,
# train_vector: -0.28|-1.03|-1.39|-2.24|-2.34|-1.13|-2.09|-2.54,
# val_vector  : +0.08|-0.64|-1.40|-2.35|-2.24|-1.15|-2.17|-2.39
#
# epoch:44, train_loss: -1.643, val_loss: -1.495,
# train_vector: -0.30|-1.06|-1.39|-2.25|-2.35|-1.13|-2.11|-2.56,
# val_vector  : +0.35|-0.59|-1.44|-2.29|-2.32|-1.17|-2.11|-2.40
#
# epoch:45, train_loss: -1.648, val_loss: -1.615,
# train_vector: -0.30|-1.05|-1.40|-2.27|-2.36|-1.14|-2.10|-2.56,
# val_vector  : -0.46|-0.77|-1.42|-2.38|-2.15|-1.16|-2.14|-2.44
#
# epoch:46, train_loss: -1.657, val_loss: -1.615,
# train_vector: -0.31|-1.06|-1.41|-2.29|-2.36|-1.14|-2.11|-2.57,
# val_vector  : -0.13|-0.90|-1.45|-2.43|-2.24|-1.17|-2.18|-2.42
# epoch:47, train_loss: -1.661, val_loss: -1.630,
# train_vector: -0.30|-1.08|-1.41|-2.27|-2.37|-1.15|-2.12|-2.59,
# val_vector  : -0.23|-1.00|-1.44|-2.37|-2.22|-1.16|-2.18|-2.43
#
# epoch:48, train_loss: -1.807, val_loss: -1.804,
# train_vector: -0.45|-1.33|-1.49|-2.43|-2.56|-1.20|-2.24|-2.75,
# val_vector  : -0.60|-1.36|-1.51|-2.49|-2.41|-1.23|-2.28|-2.55
#
# epoch:49, train_loss: -1.836, val_loss: -1.817,
# train_vector: -0.48|-1.37|-1.51|-2.47|-2.60|-1.22|-2.26|-2.79,
# val_vector  : -0.61|-1.47|-1.51|-2.43|-2.42|-1.24|-2.31|-2.55
#
# Training completed in 4143.661046743393s

# %%
save_results(train_loss_list,val_loss_list,reuse,block,\
             head,data,batch_size,dim,clip,layer1,layer2,factor,epochs)
save_model_type(bestWeight,opt,reuse,block,head,data,batch_size,dim,clip,layer1,layer2,factor,epochs)

# %% [markdown]
# Continue training

# %%
for para in opt.param_groups:
    para['lr'] = lr/2

# %%
model,train_loss_list,val_loss_list,bestWeight = train_type(opt,model,10,train_dl,val_dl,paras,clip)
# Out:
# epoch:0, train_loss: -1.847, val_loss: -1.800,
# train_vector: -0.49|-1.39|-1.51|-2.48|-2.62|-1.23|-2.27|-2.80,
# val_vector  : -0.54|-1.26|-1.51|-2.56|-2.42|-1.24|-2.27|-2.59
#
# epoch:1, train_loss: -1.856, val_loss: -1.776,
# train_vector: -0.49|-1.40|-1.52|-2.49|-2.64|-1.23|-2.28|-2.81,
# val_vector  : -0.36|-1.40|-1.50|-2.43|-2.45|-1.25|-2.24|-2.57
#
# epoch:2, train_loss: -1.871, val_loss: -1.836,
# train_vector: -0.51|-1.43|-1.53|-2.50|-2.65|-1.24|-2.29|-2.83,
# val_vector  : -0.51|-1.49|-1.53|-2.59|-2.44|-1.25|-2.30|-2.57
#
# epoch:3, train_loss: -1.874, val_loss: -1.827,
# train_vector: -0.51|-1.42|-1.53|-2.51|-2.66|-1.24|-2.30|-2.83,
# val_vector  : -0.57|-1.34|-1.53|-2.56|-2.47|-1.25|-2.31|-2.58
#
# epoch:4, train_loss: -1.880, val_loss: -1.806,
# train_vector: -0.51|-1.44|-1.53|-2.52|-2.66|-1.24|-2.29|-2.85,
# val_vector  : -0.30|-1.39|-1.54|-2.57|-2.48|-1.26|-2.31|-2.60
#
# epoch:5, train_loss: -1.881, val_loss: -1.859,
# train_vector: -0.51|-1.42|-1.54|-2.52|-2.66|-1.24|-2.30|-2.85,
# val_vector  : -0.65|-1.49|-1.53|-2.58|-2.48|-1.26|-2.31|-2.57
#
# epoch:6, train_loss: -1.891, val_loss: -1.776,
# train_vector: -0.52|-1.44|-1.54|-2.53|-2.68|-1.25|-2.30|-2.86,
# val_vector  : -0.27|-1.18|-1.53|-2.58|-2.47|-1.26|-2.33|-2.59
#
# epoch:7, train_loss: -1.891, val_loss: -1.786,
# train_vector: -0.52|-1.43|-1.55|-2.52|-2.68|-1.25|-2.31|-2.87,
# val_vector  : -0.27|-1.37|-1.54|-2.41|-2.49|-1.27|-2.31|-2.62
#
# epoch:8, train_loss: -1.898, val_loss: -1.846,
# train_vector: -0.52|-1.45|-1.55|-2.53|-2.69|-1.26|-2.31|-2.87,
# val_vector  : -0.66|-1.44|-1.54|-2.54|-2.43|-1.26|-2.31|-2.59
#
# epoch:9, train_loss: -1.907, val_loss: -1.853,
# train_vector: -0.54|-1.46|-1.55|-2.55|-2.70|-1.26|-2.32|-2.88,
# val_vector  : -0.60|-1.50|-1.56|-2.48|-2.48|-1.27|-2.31|-2.62
#
# Training completed in 835.2369387149811s

# %%
save_results(train_loss_list,val_loss_list,reuse,block,\
             head,data,batch_size,dim,clip,layer1,layer2,factor,epochs)
save_model_type(bestWeight,opt,reuse,block,head,data,batch_size,dim,clip,layer1,layer2,factor,epochs)

# %% [markdown]
# ### make submissions

# %%
def make_submission(reuse,block,head,data,batch_size,dim,clip,layer1,layer2,factor,epochs,postStr='base'):
    # set up
    model = GNN_edgeUpdate(reuse,block,head,dim,layer1,layer2,factor,**data_dict[data]).to('cuda:0')
    submission = pd.read_csv('../Data/sample_submission.csv')
    
    for i in range(8):
        # load test data and type_id
        with open(data.format('test').split('pickle')[0][:-1]+'_type_'+str(i)+'.pickle', 'rb') as handle:
            test_data = pickle.load(handle)
        test_list = [Data(**d) for d in test_data]
        test_dl = DataLoader(test_list,batch_size,shuffle=False)
        with open(data.format('test').split('pickle')[0][:-1]+'_id_type_'+str(i)+'.pickle', 'rb') as handle:
            test_id = pickle.load(handle)
    
    
        # load model
        checkpoint = torch.load('../Model/{}.tar'.format('_'.join([str(i).split('}')[1] if '}' in str(i) else str(i) \
                                            for i in [reuse,block,head,data,batch_size,dim,clip,\
                                                  layer1,layer2,factor,epochs,'type_'+str(i)+postStr]])))
        model.load_state_dict(checkpoint['model_state_dict'])
    
    
        # predict
        model.eval()
        yhat_list = []
        with torch.no_grad():
            for data_torch in test_dl:
                data_torch = data_torch.to('cuda:0')
                yhat_list.append(model(data_torch,False,True))
        yhat = torch.cat(yhat_list).cpu().detach().numpy()        
        
        # join
        submit_ = dict(zip(test_id,yhat))
        submission['type_'+str(i)] = submission.id.map(submit_)
    
    # save types results    
    submission.to_csv('../Submission/{}.csv'.format('_'.join([str(i).split('}')[1] if '}' in str(i) else str(i) \
                                        for i in [reuse,block,head,data,batch_size,dim,clip,\
                                              layer1,layer2,factor,epochs,'all_types'+postStr]])),\
                      index=False)
    
    # save final results for submission
    submission['scalar_coupling_constant'] = submission.iloc[:,2:].mean(1)
    submission = submission[['id','scalar_coupling_constant']]
    
    submission.to_csv('../Submission/{}.csv'.format('_'.join([str(i).split('}')[1] if '}' in str(i) else str(i) \
                                        for i in [reuse,block,head,data,batch_size,dim,clip,\
                                              layer1,layer2,factor,epochs,'final'+postStr]])),\
                      index=False)

# %%
make_submission(reuse,block,head,data,batch_size,dim,clip,layer1,layer2,factor,epochs)
